# %% [markdown]
# ## Laboratório 3: VQE

# %% [markdown]
# ### 1 - Circuitos Parametrizados

# %%
# Ignorando Warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# A. Imports
from qiskit import QuantumCircuit, Aer
from qiskit.circuit import Parameter, ParameterVector
import numpy as np

# %%
# B. Criando Circuitos: Parameter

qc_single = QuantumCircuit(1,1)

theta = Parameter('θ')

qc_single.ry(theta, 0)
qc_single.measure([0],[0])
qc_single.draw('mpl')

# %%
# C. Avaliando Circuitos: Parameter
v_single = np.pi/2
qc = qc_single.bind_parameters({theta:v_single})
qc.draw('mpl')

# %%
# D. Criando Circuitos: ParameterVector
n = 3

qc_multiple = QuantumCircuit(n,n)

beta = ParameterVector('β', n)

qc_multiple = QuantumCircuit(n,n)

for x in range(n):
    qc_multiple.rx(beta[x], x)

qc_multiple.measure(range(n),range(n))
qc_multiple.draw('mpl')

# %%
# E. Avaliando Circuitos: ParameterVector
v_multiple = np.linspace(0, np.pi, n)
bind_qc_multiple = qc_multiple.bind_parameters({beta: v_multiple})

bind_qc_multiple.draw('mpl')

# %% [markdown]
# ### 2 - VQE

# %%
from qiskit.aqua.operators import StateFn, I, X, Y, Z
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2.1 - Observável Z

# %%
#-- Circuito

angle = 0
qc = QuantumCircuit(1)

qc.rx(angle, 0)

#-- Valor Esperado
observable = Z 
state = StateFn(qc)
expectation_value = (~state @ observable @ state).eval()
#-- Plots
print('Valor Esperado:', expectation_value.real, '\n')
print('Circuito:')
display(qc.draw('mpl'))
# Out:
# Operator([[ 1.+0.j,  0.+0.j],
#           [ 0.+0.j, -1.+0.j]],
#          input_dims=(2,), output_dims=(2,))
# Valor Esperado: 1.0
#
# Circuito:

# %%
a = Parameter('⍺')
qc_p = QuantumCircuit(1)
qc_p.rx(a,0)

values = np.linspace(0, 2*np.pi, 20)
E = []
for x in values:
    bind_qc_p = qc_p.bind_parameters({a: x})
    state = StateFn(bind_qc_p)
    expectation_value = (~state @ observable @ state).eval()
    E.append(expectation_value.real)

plt.plot(E)  
plt.show()

# %% [markdown]
# #### 2.2 - Observável ZZ

# %%
#-- Circuito

angle = 0.1
qc_zz = QuantumCircuit(2)

qc_zz.rx(angle, 0)
qc_zz.rx(angle, 1)

#-- Valor Esperado
observable_zz = Z^Z 
state = StateFn(qc_zz)
expectation_value = (~state @ observable_zz @ state).eval()

#-- Plots
print('Valor Esperado:', expectation_value.real, '\n')
print('Circuito:')
display(qc.draw('mpl'))
# Out:
# Valor Esperado: 0.9900332889206209
#
# Circuito:

# %%
a = Parameter('⍺')
b = Parameter('β')
qc_zz_p = QuantumCircuit(2)
qc_zz_p.rx(a,0)
qc_zz_p.rx(b,1)

values = np.linspace(0, np.pi, 20)
E = []
for x in values:
    bind_qc_zz_p = qc_zz_p.bind_parameters({a: x, b:x})
    state = StateFn(bind_qc_zz_p)
    expectation_value = (~state @ observable_zz @ state).eval()
    E.append(expectation_value.real)

plt.plot(E)  
plt.show()

# %% [markdown]
# #### 2.3 - Otimização

# %%
def quantum_circuit(params):
    qc = QuantumCircuit(1)
    qc.u3(params[0], params[1], params[2], 0)
    return qc

# %%
def objective_function(params):
    qc = quantum_circuit(params)
    state = StateFn(qc)
    return (~state @ O @ state).eval()

# %%
O = Z
objective_function([0.1,0.1,0])
# Out:
#      ┌───────────────┐
# q_0: ┤ U3(0.1,0.1,0) ├
#      └───────────────┘
# <bound method CircuitStateFn.eval of CircuitStateFn(<qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7f09add08730>, coeff=1.0, is_measurement=False)>
# (0.9950041652780258+0j)

# %%
from qiskit.aqua.components.optimizers import COBYLA

optimizer = COBYLA(maxiter=10000, tol=0.0000001)
params = np.random.rand(3)
ret = optimizer.optimize(num_vars=3, objective_function=objective_function, initial_point=params)

# %%
objective_function(ret[0]).real
# Out:
# -0.9999999999999973

# %% [markdown]
# ### 3 - Exercícios

# %% [markdown]
# 1) Encontre a menor energia do observável
# $$2X -Y + I - 5Z$$
# através de circuitos que utilizem um, dois e três parâmetros.

# %% [markdown]
# 2) Encontre a menor energia do observável
# $$
# 2ZX - YZ
# $$
